# %%
import pandas as pd

from pymongo import MongoClient

client = MongoClient('localhost', 27017)  
db = client['Big_Data'] 
collection = db['patents'] 

# Test de la connexion
try:
    client.server_info()
    print("Connexion à la base de données réussie !")
except Exception as e:
    print("Erreur lors de la connexion à la base de données :", e)
# Out:
# Connexion à la base de données réussie !

# %% [markdown]
# Dans ce Jupyter Notebook, on a développé des requêtes de recherche pour interroger ma base de données de brevets. Ces requêtes sont flexibles, permettant à l'utilisateur de rechercher par ID, titre, inventeur, date, et bien plus encore. Pour les titres, il suffit à l'utilisateur d'entrer un mot-clé et le système affichera tous les résultats correspondants.
#
# De plus, on a créé des tables de brevets organisées par langue, offrant ainsi à l'utilisateur la possibilité de rechercher des brevets spécifiquement dans la langue de son choix. Cette fonctionnalité rend la recherche et la lecture des brevets plus conviviales et accessibles à un public plus large.

# %%
# Récupération de tous les documents de la collection
cursor = collection.find()

# Conversion des documents en un DataFrame pandas
df = pd.DataFrame(list(cursor))

# Affichage du DataFrame
df.head()
# Out:
#                         _id   Document Number Document Type Publication Date  \
# 0  662fc4ed19b05a444f63337d  DE102022133524A1            DE       2023-06-22
# 1  662fc4ed19b05a444f63337e  DE102022133535A1            DE       2023-06-22
# 2  662fc4ed19b05a444f63337f  DE102022133677A1            DE       2023-06-22
# 3  662fc4ed19b05a444f633380  DE102022133862A1            DE       2023-06-22
# 4  662fc4ed19b05a444f633381  DE102022133870A1            DE       2023-06-22
#
#                                 Title  \
# 0          Luftfahrzeugantriebssystem
# 1  BESTIMMUNG VON KRAFTSTOFFMERKMALEN
# 2  BESTIMMUNG VON KRAFTSTOFFMERKMALEN
# 3                  LEISTUNGSPARAMETER
# 4  BESTIMMUNG VON KRAFTSTOFFMERKMALEN
#
#                                             Abstract  \
# 0  Ein Antriebssystem (4) für ein Luftfahrzeug (1...
# 1  Die vorliegende Anmeldung offenbart ein Verfah...
# 2  Die vorliegende Anmeldung offenbart ein Verfah...
# 3  Die vorliegende Anmeldung offenbart ein Verfah...
# 4  Ein Verfahren (1040) zur Bestimmung eines oder...
#
#                                        Inventor Name  \
# 0  SWANN PETER (GB); BEMMENT CRAIG W (GB); HOBDAY...
# 1  SWANN PETER (GB); BEAVEN DAVID M (GB); BEMMENT...
# 2  SWANN PETER (GB); BEAVEN DAVID M (GB); BEMMENT...
# 3  SWANN PETER (GB); BEAVEN DAVID M (GB); BEMMENT...
# 4  SWANN PETER (GB); BEAVEN DAVID M (GB); BEMMENT...
#
#                        Assignee Filing Date
# 0  ROLLS ROYCE PLC (London, GB)  2022-12-15
# 1  ROLLS ROYCE PLC (London, GB)  2022-12-15
# 2  ROLLS ROYCE PLC (London, GB)  2022-12-16
# 3  ROLLS ROYCE PLC (London, GB)  2022-12-19
# 4  ROLLS ROYCE PLC (London, GB)  2022-12-19

# %%
df.shape
# Out:
# (3499, 9)

# %%
def search_patents_by_title(title_query):
    results = collection.find({'Title': {'$regex': title_query, '$options': 'i'}})
    
    df = pd.DataFrame(list(results))
    return df

# %%
results_df = search_patents_by_title('aviation')

# Display the DataFrame
print(results_df)
# Out:
#                          _id   Document Number Document Type  \
# 0   662fc4ed19b05a444f63338b       EP3184611A1            EP
# 1   662fc4ed19b05a444f63338c       EP3184611B1            EP
# 2   662fc4ed19b05a444f63338e       EP3507348A1            EP
# 3   662fc4ed19b05a444f633390       EP4202436A1            EP
# 4   662fc4ed19b05a444f633391       EP4330350A1            EP
# 5   662fc4ed19b05a444f633397     JP2022151754A            JP
# 6   662fc4ed19b05a444f63339b  WO/2012/012855A1          WIPO
# 7   662fc4ed19b05a444f63339c  WO/2017/108529A1          WIPO
# 8   662fc4ed19b05a444f63339e  WO/2018/045397A1          WIPO
# 9   662fc4ed19b05a444f63339f  WO/2019/023607A1          WIPO
# 10  662fc4ed19b05a444f6333a0  WO/2019/047407A1          WIPO
# 11  662fc4ed19b05a444f6333a2  WO/2022/256443A1          WIPO
# 12  662fc4ed19b05a444f6333a3  WO/2023/064150A2          WIPO
# 13  662fc4ed19b05a444f6333a4  WO/2023/066738A1          WIPO
# 14  662fc4ed19b05a444f6333a6  WO/2023/115185A1          WIPO
# 15  662fc4ed19b05a444f6333a7  WO/2023/126564A1          WIPO
# 16  662fc4ed19b05a444f6333a8  WO/2023/126565A1          WIPO
# 17  662fc4ed19b05a444f6333a9  WO/2023/150001A1          WIPO
# 18  662fc4ed19b05a444f6333ac  WO/2023/247316A1          WIPO
# 19  662fc4ed19b05a444f6333ad  WO/2024/003656A1          WIPO
# 20  662fc4ed19b05a444f633797          11585278            US
# 21  662fc4ed19b05a444f633798          11566193            US
# 22  662fc4ed19b05a444f633799     US20190002778            US
# 23  662fc4ed19b05a444f63379a     US20230108354            US
# 24  662fc4ed19b05a444f63379b           8628594            US
# 25  662fc4ed19b05a444f63379c     US20230109285            US
# 26  662fc4ed19b05a444f63379e          11674100            US
# 27  662fc4ed19b05a444f63379f          11098259            US
# 28  662fc4ed19b05a444f6337a0          10364399            US
# 29  662fc4ed19b05a444f6337a1          11919847            US
# 30  662fc4ed19b05a444f6337a2     US20230242822            US
# 31  662fc4ed19b05a444f6337a3          10377959            US
# 32  662fc4ed19b05a444f6337a4     US20190194559            US
# 33  662fc4ed19b05a444f6337a7          10260016            US
# 34  662fc4ed19b05a444f6337a8          10550347            US
# 35  662fc4ed19b05a444f6337b2          11827856            US
# 36  662fc4ed19b05a444f6337b3          11795402            US
# 37  662fc4ed19b05a444f6337b8     US20130131407            US
# 38  662fc4ed19b05a444f6337c1     US20190032552            US
# 39  662fc4ed19b05a444f6337e0     US20130284606            US
# 40  662fc4ed19b05a444f6337e1     US20160237361            US
# 41  662fc4ed19b05a444f6337f0     US20200239796            US
# 42  662fc4ed19b05a444f6337fe     US20230049829            US
# 43  662fc4ed19b05a444f633822          11471853            US
# 44  662fc4ed19b05a444f633831     US20220024578            US
# 34 2020-02-03 23:00:00             High octane unleaded aviation gasoline
# 35 2023-11-27 23:00:00  Systems, methods and apparatus for producing s...
# 36 2023-10-23 22:00:00  Systems, methods and apparatus for producing s...
# 37 2013-05-22 22:00:00  CATALYTIC HYDROGENATION OF HYDROXYCYCLOALKANES...
# 38 2019-01-30 23:00:00  AVIATION GASOLINE ENGINE COOLANT INJECTION SYSTEM
# 39 2013-10-30 23:00:00  ELECTROCHEMICAL PROCESS FOR CONVERSION OF BIOD...
# 40 2016-08-17 22:00:00  Electrochemical Process for Conversion of Biod...
# 41 2020-07-29 22:00:00  HOST CELLS AND METHODS FOR PRODUCING TRICYCLIC...
# 42 2023-02-15 23:00:00  PROCESS FOR THE INTEGRATED PRODUCTION OF H2 AN...
# 43 2022-10-17 22:00:00  Systems, methods and apparatus for producing s...
# 44 2022-01-26 23:00:00  Integrated engineering system that combines mu...
# 45 2023-06-07 22:00:00  PROCESS FOR PRODUCTION OF AVIATION KEROSENE FR...
# 46 1945-05-07 22:00:00                           Aviation lubricating oil
#
#                                              Abstract  \
# 0   The present invention relates to an aviation f...
# 1   The present invention relates to an aviation f...
# 2   The invention provides a process for the produ...
# 3   The present application discloses a method (10...
# 4   The present disclosure relates to biofuels, an...
# 5   To provide an aviation fuel oil having a low p...
# 6   The present patent application relates to a ne...
# 7   The present invention relates to an aviation f...
# 8   The invention provides a process for the produ...
# 9   A set of apparatus to inject distilled-water i...
# 10  A low carbon aviation biofuel preparation meth...
# 11  The present disclosure relates to biofuels, an...
# 12  Systems, methods and apparatus are provided th...
# 13  This invention provides an aviation fuel compo...
# 14  The present invention relates to a method comp...
# 15  The present invention relates to a method for ...
# 16  The present invention relates to a method for ...
# 17  A process for the production of sustainable av...
# 18  A reforming system is provided for dedicated s...
# 19  A process for making a renewable product from ...
# 20  A method of determining one or more fuel chara...
# 21  The present invention relates to an aviation f...
# 22  The present invention relates to an aviation f...
# 23  Systems, methods and apparatus are provided th...
# 24  An unleaded aviation fuel blend. The fuel blen...
# 25  Systems, methods and apparatus are provided th...
# 26  Unleaded aviation gasoline. An aviation gasoli...
# 27  Unleaded aviation gasoline. An aviation gasoli...
# 28  Method for manufacture of unleaded aviation ga...
# 29  The invention relates to an efficient, high-th...
# 30  A process for the production of sustainable av...
# 31  Unleaded aviation gasoline. An unleaded aviati...
# 32  The invention provides a process for the produ...
# 33  Unleaded aviation gasoline. An aviation gasoli...
# 34  Unleaded aviation gasoline. High quality aviat...
# 35  Systems, methods and apparatus are provided th...
# 36  Systems, methods and apparatus are provided th...
# 37  This invention relates to a new biofuel altern...
# 38  A set of apparatus to inject distilled-water i...
# 39  Methods for the conversion of a biofuel such a...
# 40  Methods for the conversion of a biofuel such a...
# 41  The present invention provides for a fuel comp...
# 42  The present invention addresses to a process f...
# 43  Systems, methods and apparatus are provided th...
# 44  An integrated engineering system integrating m...
# 45  The present invention refers to the processing...
# 35                 Kepler GTL LLC (Southlake, TX, US) 2022-02-24 23:00:00
# 36                 Kepler GTL LLC (Southlake, TX, US) 2021-10-05 22:00:00
# 37  FRAGA MARCO ANDRE                \n           ... 2011-07-27 22:00:00
# 38          Swift Fuels, LLC (West Lafayette, IN, US) 2018-07-26 22:00:00
# 39           NORTHEASTERN UNIVERSITY (Boston, MA, US) 2011-07-24 22:00:00
# 40           Northeastern University (Boston, MA, US) 2016-04-27 22:00:00
# 41  The Regents of the University of California (O... 2019-09-29 22:00:00
# 42  Petróleo Brasileiro S.A. - Petrobras (Rio de J... 2022-08-10 22:00:00
# 43                 Kepler GTL LLC (Southlake, TX, US) 2022-03-04 23:00:00
# 44                                 Assignee not found 2020-07-24 22:00:00
# 45  Petróleo Brasileiro S.A. - Petrobras (Rio de J... 2022-12-05 23:00:00
# 46                                         Shell, Dev 1943-09-14 22:00:00

# %%
from datetime import datetime  
def search_patents_by_year_pd(year_query):
    start_date = datetime(year_query, 1, 1)
    end_date = datetime(year_query, 12, 31)
    
    results = collection.find({'Publication Date': {'$gte': start_date, '$lte': end_date}})
    
    df = pd.DataFrame(list(results))
    return df

def search_patents_by_year_fd(year_query):
    start_date = datetime(year_query, 1, 1)
    end_date = datetime(year_query, 12, 31)
    
    results = collection.find({'Filing Date': {'$gte': start_date, '$lte': end_date}})
    
    df = pd.DataFrame(list(results))
    return df

# %%
def search_patents_by_inventor(inventor_query):
    results = collection.find({'Inventor Name': {'$regex': inventor_query, '$options': 'i'}})
    
    df = pd.DataFrame(list(results))
    return df

# %%
# Search for patents filed in the year 2024
results_year_df = search_patents_by_year_pd(2023)
print("Results for year query:")
print(results_year_df)
# Out:
# Results for year query:
#                           _id   Document Number Document Type  \
# 0    662fc4ed19b05a444f63337d  DE102022133524A1            DE
# 1    662fc4ed19b05a444f63337e  DE102022133535A1            DE
# 2    662fc4ed19b05a444f63337f  DE102022133677A1            DE
# 3    662fc4ed19b05a444f633380  DE102022133862A1            DE
# 4    662fc4ed19b05a444f633381  DE102022133870A1            DE
# ..                        ...               ...           ...
# 426  662fc4ed19b05a444f6340c4     US20230002037            US
# 427  662fc4ed19b05a444f6340ca     US20230306218            US
# 428  662fc4ed19b05a444f6340d8     US20230390744            US
# 429  662fc4ed19b05a444f6340e5          11825863            US
# 430  662fc4ed19b05a444f634104     US20230136731            US
#
#        Publication Date                                              Title  \
# 0   2023-06-22 00:00:00                         Luftfahrzeugantriebssystem
# 1   2023-06-22 00:00:00                 BESTIMMUNG VON KRAFTSTOFFMERKMALEN
# 2   2023-06-22 00:00:00                 BESTIMMUNG VON KRAFTSTOFFMERKMALEN
# 3   2023-06-22 00:00:00                                 LEISTUNGSPARAMETER
# 4   2023-06-22 00:00:00                 BESTIMMUNG VON KRAFTSTOFFMERKMALEN
# ..                  ...                                                ...
# 426 2023-01-04 23:00:00  AIRCRAFT FOR COMMERCIAL AIR TRAVEL AND A METHO...
# 427 2023-09-27 22:00:00  METHOD FOR TRACEABILITY OF RAW MATERIALS, COMP...
# 428 2023-12-06 23:00:00  METHODS AND CATALYSTS FOR CARBON DIOXIDE CONVE...
# 429 2023-11-27 23:00:00  Method for removing glucosinolates from oilsee...
# 430 2023-05-03 22:00:00  BATTERY SYSTEM AND METHOD OF AN ELECTRIC AIRCR...
#
#                                               Abstract  \
# 0    Ein Antriebssystem (4) für ein Luftfahrzeug (1...
# 1    Die vorliegende Anmeldung offenbart ein Verfah...
# 2    Die vorliegende Anmeldung offenbart ein Verfah...
# 3    Die vorliegende Anmeldung offenbart ein Verfah...
# 4    Ein Verfahren (1040) zur Bestimmung eines oder...
# ..                                                 ...
# 426  Aspects related to aircraft for commercial air...
# 427  A method for traceability of raw materials or ...
# 428  The present disclosure provides catalysts, rea...
# 429  A process to remove the glucosinolates of oils...
# 430  A system for a battery with spring conductors ...
#
#                                          Inventor Name  \
# 0    SWANN PETER (GB); BEMMENT CRAIG W (GB); HOBDAY...
# 1    SWANN PETER (GB); BEAVEN DAVID M (GB); BEMMENT...
# 2    SWANN PETER (GB); BEAVEN DAVID M (GB); BEMMENT...
# 3    SWANN PETER (GB); BEAVEN DAVID M (GB); BEMMENT...
# 4    SWANN PETER (GB); BEAVEN DAVID M (GB); BEMMENT...
# ..                                                 ...
# 426                     Page, Mark A. (Orange, CA, US)
# 427  Kayalar, Mete (Istanbul, TR)                \n...
# 428  Sheehan, Stafford W. (Tiverton, RI, US)       ...
# 429  Hetherington, Mark (Saskatoon, CA)            ...
# 430           Wiegman, Herman (Essex Junction, VT, US)
#
#                                           Assignee         Filing Date
# 0                     ROLLS ROYCE PLC (London, GB) 2022-12-15 00:00:00
# 1                     ROLLS ROYCE PLC (London, GB) 2022-12-15 00:00:00
# 2                     ROLLS ROYCE PLC (London, GB) 2022-12-16 00:00:00
# 3                     ROLLS ROYCE PLC (London, GB) 2022-12-19 00:00:00
# 4                     ROLLS ROYCE PLC (London, GB) 2022-12-19 00:00:00
# ..                                             ...                 ...
# 426   Blended Wing Aircraft, Inc. (Orange, CA, US) 2022-08-24 22:00:00
# 427                COSMODOT INC. (Houston, TX, US) 2022-03-24 23:00:00
# 428  Air Company Holdings, Inc. (Brooklyn, NY, US) 2023-08-07 22:00:00
# 429       AGRISOMA BIOSCIENCES INC. (Gatineau, CA) 2016-11-28 23:00:00
# 430       BETA AIR, LLC (SOUTH BURLINGTON, VT, US) 2021-09-14 22:00:00
#
# [431 rows x 9 columns]

# %%
def select_data_by_language(language):
    csv_file_path = f"C:\\Users\\hp\\id2\\bg\\idiomas\\{language}_titles.csv"

    try:
        df = pd.read_csv(csv_file_path)

        print(df.head())
    except FileNotFoundError:
        print(f"Le fichier CSV pour la langue '{language}' n'a pas été trouvé.")

select_data_by_language('ja')
# Out:
#   Document Number Document Type Publication Date  \
# 0   JP2012519768A            JP       2012-08-30
# 1   JP2019518823A            JP       2019-07-04
# 2   JP2019529613A            JP       2019-10-17
# 3   JP2020511350A            JP       2020-04-16
# 4   JP2024506450A            JP       2024-02-14
#
#                                                Title  \
# 0                           バイオマスからの有機化合物を一部含有する航空燃料
# 1          バイオ再生可能ケロシン、ジェット燃料、ジェット燃料ブレンドストック、および製造方法
# 2           合成由来の代替航空タービン燃料である、合成パラフィンケロシン（ＳＰＫ）の製造方法
# 3                                無人航空車両のための電力システムの冷却
# 4  炭素回収を利用する化学物質および燃料を製造するプラントのための、コンピュータで実行されるモニ...
#
#                                             Abstract  \
# 0  The invention relates to an aviation fuel cont...
# 1  本技術は、他の驚くべき特徴の中でも、ディーゼル燃料、航空燃料、ジェット燃料ブレンドストック、...
# 2  本発明は、航空タービン燃料の製造方法を提供する。本方法は、高温フィッシャー・トロプシュ法に由...
# 3  無人航空車両は、回転するように少なくとも１つのプロペラを駆動するように構成される、少なくとも...
# 4  本開示は、ブループラントのためのコンピュータで実行されるモニタリング方法であって、前記プラン...
#
#                                        Inventor Name  \
# 0                             Deyubois, Jiyan-Liyusk
# 1  Aberramine; Slade David A.; Tom Linson H. Lynn...
# 2  Mudreleni Masikana Milan; Nottenbelt Cyril Dav...
# 3  Fan, Long N.; Imani Nejad, Mohammad; Sweetland...
# 4  Wilbek Feey Alice Hallqvist; Boyson Anders Eri...
#
#                                             Assignee Filing Date
# 0                                      Arkema France  2010-03-08
# 1   R Easy Synthetic Fuels Limited Liability Company  2017-05-10
# 2  THE PETROLEUM OIL AND GAS CORPORATION OF SOUTH...  2017-08-28
# 3                      Top Flight Technologies, Inc.  2018-03-09
# 4                              Topso Actiesel Scavet  2021-12-22

# %%
def search_patents_by_document_type(document_type_query):
    results = collection.find({'Document Type': {'$regex': document_type_query, '$options': 'i'}})
    df = pd.DataFrame(list(results))
    return df

# %%
# Rechercher des brevets par type de document
document_type_query = "WIPO"
document_type_results = search_patents_by_document_type(document_type_query)

# %%
document_type_results.head()
# Out:
#                         _id   Document Number Document Type Publication Date  \
# 0  662fc4ed19b05a444f63339b  WO/2012/012855A1          WIPO       2012-02-02
# 1  662fc4ed19b05a444f63339c  WO/2017/108529A1          WIPO       2017-06-29
# 2  662fc4ed19b05a444f63339d  WO/2017/197017A1          WIPO       2017-11-16
# 3  662fc4ed19b05a444f63339e  WO/2018/045397A1          WIPO       2018-03-08
# 4  662fc4ed19b05a444f63339f  WO/2019/023607A1          WIPO       2019-01-31
#
#                                                Title  \
# 0  CATALYTIC HYDROGENATION OF HYDROXYCYCLOALKANES...
# 1                          AVIATION FUEL COMPOSITION
# 2  BIORENEWABLE KEROSENE, JET FUEL, JET FUEL BLEN...
# 3  METHOD TO PRODUCE AN ALTERNATIVE SYNTHETICALLY...
# 4  AVIATION GASOLINE ENGINE COOLANT INJECTION SYSTEM
#
#                                             Abstract  \
# 0  The present patent application relates to a ne...
# 1  The present invention relates to an aviation f...
# 2  The present technology provides compositions t...
# 3  The invention provides a process for the produ...
# 4  A set of apparatus to inject distilled-water i...
#
#                                        Inventor Name  \
# 0  FRAGA MARCO ANDRE (BR); BORGES LUIZ EDUARDO PI...
# 1               SANDBERG KATI (FI); KIISKI ULLA (FI)
# 2  ABHARI RAMIN (US); SLADE DAVID A (US); TOMLINS...
# 3  MDLELENI MASIKANA MILLAN (ZA); KNOTTENBELT CYR...
# 4  D'ACOSTA CHRIS (US); STIRM BRIAN (US); ALBUZAT...
#
#                                             Assignee Filing Date
# 0  INT INST NAC DE TECNOLOGIA (BR); INST MILITAR ...  2011-07-28
# 1                                    NESTE CORP (FI)  2016-12-14
# 2                       REG SYNTHETIC FUELS LLC (US)  2017-05-10
# 3  THE PETROLEUM OIL & GAS CORP OF SOUTH AFRICA P...  2017-08-28
# 4  DACOSTA CHRIS (US); STIRM BRIAN (US); ALBUZAT ...  2018-07-27

# %%
# Rechercher des brevets par type de document
document_type_query = "wipo"
document_type_results = search_patents_by_document_type(document_type_query)
document_type_results.head()
# Out:
#                         _id   Document Number Document Type Publication Date  \
# 0  662fc4ed19b05a444f63339b  WO/2012/012855A1          WIPO       2012-02-02
# 1  662fc4ed19b05a444f63339c  WO/2017/108529A1          WIPO       2017-06-29
# 2  662fc4ed19b05a444f63339d  WO/2017/197017A1          WIPO       2017-11-16
# 3  662fc4ed19b05a444f63339e  WO/2018/045397A1          WIPO       2018-03-08
# 4  662fc4ed19b05a444f63339f  WO/2019/023607A1          WIPO       2019-01-31
#
#                                                Title  \
# 0  CATALYTIC HYDROGENATION OF HYDROXYCYCLOALKANES...
# 1                          AVIATION FUEL COMPOSITION
# 2  BIORENEWABLE KEROSENE, JET FUEL, JET FUEL BLEN...
# 3  METHOD TO PRODUCE AN ALTERNATIVE SYNTHETICALLY...
# 4  AVIATION GASOLINE ENGINE COOLANT INJECTION SYSTEM
#
#                                             Abstract  \
# 0  The present patent application relates to a ne...
# 1  The present invention relates to an aviation f...
# 2  The present technology provides compositions t...
# 3  The invention provides a process for the produ...
# 4  A set of apparatus to inject distilled-water i...
#
#                                        Inventor Name  \
# 0  FRAGA MARCO ANDRE (BR); BORGES LUIZ EDUARDO PI...
# 1               SANDBERG KATI (FI); KIISKI ULLA (FI)
# 2  ABHARI RAMIN (US); SLADE DAVID A (US); TOMLINS...
# 3  MDLELENI MASIKANA MILLAN (ZA); KNOTTENBELT CYR...
# 4  D'ACOSTA CHRIS (US); STIRM BRIAN (US); ALBUZAT...
#
#                                             Assignee Filing Date
# 0  INT INST NAC DE TECNOLOGIA (BR); INST MILITAR ...  2011-07-28
# 1                                    NESTE CORP (FI)  2016-12-14
# 2                       REG SYNTHETIC FUELS LLC (US)  2017-05-10
# 3  THE PETROLEUM OIL & GAS CORP OF SOUTH AFRICA P...  2017-08-28
# 4  DACOSTA CHRIS (US); STIRM BRIAN (US); ALBUZAT ...  2018-07-27
